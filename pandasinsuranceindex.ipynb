# %%
""" loading real datasets in pandas """
import pandas as pd
import numpy as np

# %%
insurance = pd.read_csv(r'C:\Users\jeffnerd\Desktop\insurance.csv')

# %%
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
insurance[['age','sex','bmi','children','smoker']]
# Out:
#       age     sex     bmi  children smoker
# 0      19  female  27.900         0    yes
# 1      18    male  33.770         1     no
# 2      28    male  33.000         3     no
# 3      33    male  22.705         0     no
# 4      32    male  28.880         0     no
# 5      31  female  25.740         0     no
# 6      46  female  33.440         1     no
# 7      37  female  27.740         3     no
# 8      37    male  29.830         2     no
# 9      60  female  25.840         0     no
# 10     25    male  26.220         0     no
# 11     62  female  26.290         0    yes
# 12     23    male  34.400         0     no
# 13     56  female  39.820         0     no
# 14     27    male  42.130         0    yes
# 15     19    male  24.600         1     no
# 16     52  female  30.780         1     no
# 17     23    male  23.845         0     no
# 18     56    male  40.300         0     no
# 19     30    male  35.300         0    yes
# 20     60  female  36.005         0     no
# ...

# %%
insurance[:1000]
# Out:
#      age     sex     bmi  children smoker     region      charges
# 0     19  female  27.900         0    yes  southwest  16884.92400
# 1     18    male  33.770         1     no  southeast   1725.55230
# 2     28    male  33.000         3     no  southeast   4449.46200
# 3     33    male  22.705         0     no  northwest  21984.47061
# 4     32    male  28.880         0     no  northwest   3866.85520
# 5     31  female  25.740         0     no  southeast   3756.62160
# 6     46  female  33.440         1     no  southeast   8240.58960
# 7     37  female  27.740         3     no  northwest   7281.50560
# 8     37    male  29.830         2     no  northeast   6406.41070
# 9     60  female  25.840         0     no  northwest  28923.13692
# 10    25    male  26.220         0     no  northeast   2721.32080
# 11    62  female  26.290         0    yes  southeast  27808.72510
# 12    23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
insurance.iloc[3:500,:]
# Out:
#      age     sex     bmi  children smoker     region      charges
# 3     33    male  22.705         0     no  northwest  21984.47061
# 4     32    male  28.880         0     no  northwest   3866.85520
# 5     31  female  25.740         0     no  southeast   3756.62160
# 6     46  female  33.440         1     no  southeast   8240.58960
# 7     37  female  27.740         3     no  northwest   7281.50560
# 8     37    male  29.830         2     no  northeast   6406.41070
# 9     60  female  25.840         0     no  northwest  28923.13692
# 10    25    male  26.220         0     no  northeast   2721.32080
# 11    62  female  26.290         0    yes  southeast  27808.72510
# 12    23    male  34.400         0     no  southwest   1826.84300
# 13    56  female  39.820         0     no  southeast  11090.71780
# 14    27    male  42.130         0    yes  southeast  39611.75770
# 15    19    male  24.600         1     no  southwest   1837.23700
# ...

# %%
insurance.iloc[4:700,:]
# Out:
#      age     sex     bmi  children smoker     region      charges
# 4     32    male  28.880         0     no  northwest   3866.85520
# 5     31  female  25.740         0     no  southeast   3756.62160
# 6     46  female  33.440         1     no  southeast   8240.58960
# 7     37  female  27.740         3     no  northwest   7281.50560
# 8     37    male  29.830         2     no  northeast   6406.41070
# 9     60  female  25.840         0     no  northwest  28923.13692
# 10    25    male  26.220         0     no  northeast   2721.32080
# 11    62  female  26.290         0    yes  southeast  27808.72510
# 12    23    male  34.400         0     no  southwest   1826.84300
# 13    56  female  39.820         0     no  southeast  11090.71780
# 14    27    male  42.130         0    yes  southeast  39611.75770
# 15    19    male  24.600         1     no  southwest   1837.23700
# 16    52  female  30.780         1     no  northeast  10797.33620
# ...

# %%
insurance[lambda x: 'sex']
# Out:
# 0       female
# 1         male
# 2         male
# 3         male
# 4         male
# 5       female
# 6       female
# 7       female
# 8         male
# 9       female
# 10        male
# 11      female
# 12        male
# 13      female
# 14        male
# 15        male
# 16      female
# 17        male
# 18        male
# 19        male
# 20      female
# 21      female
# 22        male
# 23      female
# 24        male
# 25      female
# 26      female
# 27      female
# 28        male
# 29        male
#          ...
# 1308    female
# 1309      male
# 1310      male
# 1311    female
# 1312      male
# 1313    female
# 1314    female
# 1315      male
# 1316    female
# 1317      male
# 1318      male
# 1319    female
# 1320      male
# 1321      male
# 1322      male
# 1323    female
# 1324      male
# 1325      male
# 1326    female
# 1327      male
# 1328    female
# 1329      male
# 1330    female
# 1331    female
# 1332    female
# 1333      male
# 1334    female
# ...

# %%
insurance[lambda x: ['sex','bmi']]
# Out:
#          sex     bmi
# 0     female  27.900
# 1       male  33.770
# 2       male  33.000
# 3       male  22.705
# 4       male  28.880
# 5     female  25.740
# 6     female  33.440
# 7     female  27.740
# 8       male  29.830
# 9     female  25.840
# 10      male  26.220
# 11    female  26.290
# 12      male  34.400
# 13    female  39.820
# 14      male  42.130
# 15      male  24.600
# 16    female  30.780
# 17      male  23.845
# 18      male  40.300
# 19      male  35.300
# 20    female  36.005
# 21    female  32.400
# 22      male  34.100
# 23    female  31.920
# 24      male  28.025
# 25    female  27.720
# 26    female  23.085
# 27    female  32.775
# 28      male  17.385
# 29      male  36.300
# ...      ...     ...
# 1308  female  30.200
# 1309    male  32.200
# 1310    male  26.315
# 1311  female  26.695
# 1312    male  42.900
# 1313  female  34.700
# 1314  female  23.655
# 1315    male  28.310
# 1316  female  20.600
# 1317    male  53.130
# 1318    male  39.710
# ...

# %%
insurance.set_index(['sex', 'smoker'])
# Out:
#                age     bmi  children     region      charges
# sex    smoker
# female yes      19  27.900         0  southwest  16884.92400
# male   no       18  33.770         1  southeast   1725.55230
#        no       28  33.000         3  southeast   4449.46200
#        no       33  22.705         0  northwest  21984.47061
#        no       32  28.880         0  northwest   3866.85520
# female no       31  25.740         0  southeast   3756.62160
#        no       46  33.440         1  southeast   8240.58960
#        no       37  27.740         3  northwest   7281.50560
# male   no       37  29.830         2  northeast   6406.41070
# female no       60  25.840         0  northwest  28923.13692
# male   no       25  26.220         0  northeast   2721.32080
# female yes      62  26.290         0  southeast  27808.72510
# male   no       23  34.400         0  southwest   1826.84300
# female no       56  39.820         0  southeast  11090.71780
# ...

# %%
insurance.reset_index()
# Out:
#       index  age     sex     bmi  children smoker     region      charges
# 0         0   19  female  27.900         0    yes  southwest  16884.92400
# 1         1   18    male  33.770         1     no  southeast   1725.55230
# 2         2   28    male  33.000         3     no  southeast   4449.46200
# 3         3   33    male  22.705         0     no  northwest  21984.47061
# 4         4   32    male  28.880         0     no  northwest   3866.85520
# 5         5   31  female  25.740         0     no  southeast   3756.62160
# 6         6   46  female  33.440         1     no  southeast   8240.58960
# 7         7   37  female  27.740         3     no  northwest   7281.50560
# 8         8   37    male  29.830         2     no  northeast   6406.41070
# 9         9   60  female  25.840         0     no  northwest  28923.13692
# 10       10   25    male  26.220         0     no  northeast   2721.32080
# 11       11   62  female  26.290         0    yes  southeast  27808.72510
# ...

# %%
insurance.set_index('age', drop=False,inplace=True)

# %%
insurance
# Out:
#      age     sex     bmi  children smoker     region      charges
# age
# 19    19  female  27.900         0    yes  southwest  16884.92400
# 18    18    male  33.770         1     no  southeast   1725.55230
# 28    28    male  33.000         3     no  southeast   4449.46200
# 33    33    male  22.705         0     no  northwest  21984.47061
# 32    32    male  28.880         0     no  northwest   3866.85520
# 31    31  female  25.740         0     no  southeast   3756.62160
# 46    46  female  33.440         1     no  southeast   8240.58960
# 37    37  female  27.740         3     no  northwest   7281.50560
# 37    37    male  29.830         2     no  northeast   6406.41070
# 60    60  female  25.840         0     no  northwest  28923.13692
# 25    25    male  26.220         0     no  northeast   2721.32080
# 62    62  female  26.290         0    yes  southeast  27808.72510
# 23    23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
insurance.set_index(['age','smoker','region'], append=True)
# Out:
#                              sex     bmi  children      charges
# age age smoker region
# 19  19  yes    southwest  female  27.900         0  16884.92400
# 18  18  no     southeast    male  33.770         1   1725.55230
# 28  28  no     southeast    male  33.000         3   4449.46200
# 33  33  no     northwest    male  22.705         0  21984.47061
# 32  32  no     northwest    male  28.880         0   3866.85520
# 31  31  no     southeast  female  25.740         0   3756.62160
# 46  46  no     southeast  female  33.440         1   8240.58960
# 37  37  no     northwest  female  27.740         3   7281.50560
#                northeast    male  29.830         2   6406.41070
# 60  60  no     northwest  female  25.840         0  28923.13692
# 25  25  no     northeast    male  26.220         0   2721.32080
# 62  62  yes    southeast  female  26.290         0  27808.72510
# 23  23  no     southwest    male  34.400         0   1826.84300
# ...
